# %%
import requests
from bs4 import BeautifulSoup

# %%
hs = {
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'
}

# %%
with requests.Session() as s:
    url = 'http://hyint.nhu.edu.tw/nhuhyint/LoginCheck.jsp'
    target = 'http://hyint.nhu.edu.tw/nhuhyint/sendurl_api_v3.jsp?dbid=DB17143'
    r = s.get(target, headers=hs)
    soup = BeautifulSoup(r.content, 'html5lib')
    token = soup.find('input', attrs={'name': 'csrf'})['value']
    logintime = soup.find('input',attrs={'name':'url'})['value']
    Parse = logintime.split('=',5)
    time = ''+Parse[5]
    login_data = dict(csrf=token,
                      url="sendurl_api_v3.jsp?debug=&dbid=DB17143&type=&url=http://www.airitilibrary.com&logintime="+time,
                      uid="10525123",
                      pwd="a524700a")
    '''
    uid = 登入帳號
    pwd = 登入密碼
    '''
    #訪問網址
    Access_Page = "http://hyint.nhu.edu.tw:2048/login"
    Access_data = {
        'url': "http://www.airitilibrary.com",
        'user': "10525123",
        'pass': "MWJiMmNiZTBhMThhYmQ5Yw==" #怕
    }

    page = 'http://hyint.nhu.edu.tw:2048/login'
    r = s.post(url, data=login_data, headers=hs)
    r = s.post(Access_Page,data=Access_data,headers=hs)
    a = s.get("http://hyint.nhu.edu.tw:2053/")
    print(a.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
#   <meta content="期刊，論文，期刊論文，中文，電子期刊，華藝，CEPS，中文期刊，學術期刊，期刊文章，文章，全文下載，論文下載, CETD, 碩博士論文, 博碩士論文, 學位論文, 會議論文, 研討會, GCScholar, GCS, 華文, 電子全文, PDF, 免費PDF, 免費全文, 學術文獻, 圖書館, 電子資料庫, 全文資料庫, 資料庫, Airiti, article, 台大論文, 國家圖書館, 思博網, 查資料, 國圖, Journal, Airiti Library, Library, 華藝線上圖書館, DOI, DOI申請, DOI註冊 "
#         name="keywords" />
#   <meta content="Airiti Library華藝線上圖書館" name="description" />
#   <meta http-equiv="imagetoolbar" content="no" />
#   <meta http-equiv="Expires" content="Wed, 26 Feb 1950 08:21:57 GMT" />
#   <meta http-equiv="Pragma" content="no-cache" />
#   <meta name="robots" content="nofollow,noarchive" />
#   <title>Airiti Library華藝線上圖書館</title>
#   <link id="shortcut_icon" type="image/x-icon" href="/Content/images/favicon.ico" rel="shortcut icon" />
#
#
#   <link href="/Content/css/_Layout_tw?v=KkSnpqQgi3cyOqm13u5S199Az3QPnZD_pOyRw6Z_voQ1" rel="stylesheet"/>
#
#   <script src="/Scripts/_Layout?v=U_4-DfVnihRI6HMEAgclblOiA_Bjqr1hIPT5Ho-8bMo1"></script>
#
#   <script src="https://www.google.com/recaptcha/api.js?onload=onloadCallback&render=explicit" async=async async=async defer=defer defer=defer></script>
#
#
#
#   <script language="javascript" type="text/javascript">
#     //前端多國語言物件
#     var Resources = new Object();
#
#     $(document).ready(function () {
#       try {
#         Resources.ResLan_DataProcessingPlease = '資料處理中，請稍候';
#         Resources.ResLan_DownloadProcessingPlease = '檔案下載處理中，請稍候';
#         Resources.ResLan_ConfirmDownloadFull = '確認下載全文';
#         Resources.ResLan_DownloadFullTime = '下載全文時，請先確認您的';
#         Resources.ResLan_Version70Or = '為7.0以上版本';
#         Resources.ResLan_IfYouDownload = '，若您下載文章含簡體內碼，也請一併增加下載';
#         Resources.ResLan_EmbeddedChineseSuite = '內嵌中文套件';
#         Resources.ResLan_ToAvoidNot = '，以避免無法瀏覽。';
#         Resources.ResLan_Count = '點數';
#         Resources.ResLan_ColonFull = '：';
#         Resources.ResLan_IfYourIP = '；若您所在IP為團體客戶IP，且該客戶已採購或試用該篇文章所屬資料庫，則您所下載的文章不扣點，並納入您個人使用記錄。';
#         Resources.ResLan_AfterConfirmingDeduction = '確認扣點後，此篇電子全文24小時內，於本資料庫下載將不重複扣點。感謝您的使用！';
#         Resources.ResLan_PleaseEnterTheCode1 = '請輸入驗證碼';
#         Resources.ResLan_DownloadCaptchaImage = '下載中-驗證碼圖片';
#         Resources.ResLan_CaptchaImage = '驗證碼圖片';
#         Resources.ResLan_UpdateVerificationCode = '更新驗證碼';
#         Resources.ResLan_VerificationCodeErrors = '驗證碼錯誤，請重新輸入';
#         Resources.ResLan_ExclamationFull = '！';
#         Resources.ResLan_SorryDueTo = '很抱歉，因為網路問題，或系統偵測到您可能不是由AL前台使用全文下載功能，請重新由AL前台查詢並使用全文下載功能，謝謝！';
#         Resources.ResLan_Ok = '確定';
#         Resources.ResLan_Cancel = '取消';
#         Resources.ResLan_PleaseReclick = '請再重新點擊';
#         Resources.ResLan_DownloadHostConnection = '下載發生主機連線問題，請聯絡客服人員，或請稍晚再行使用，謝謝！';
#         Resources.ResLan_DownloadCongestionProblem = '下載發生網路連線壅塞問題，或請稍晚再行使用，謝謝！';
#         Resources.ResLan_SorryToInform = '很抱歉通知您，目前檔案系統處理忙碌中，請您於離峰時間再使用，若點數已被扣取，請轉知客服同仁為您服務，感謝！';
#         Resources.ResLan_QueryResultsOver = '查詢結果逾時語言工具書，請回到前一頁面或首頁，重新進行查詢！';
#         Resources.ResLan_20170001 = '確認閱讀語言';
#         Resources.ResLan_20170002 = '(限中文文字型PDF)';
#         Resources.ResLan_20170003 = '以簡體中文開啟';
#         Resources.ResLan_20170004 = '圖片型，已加密及使用特殊字型的PDF無法以簡體中文開啟';
#         Resources.ResLan_20170005 = '文檔閱讀器';
#         Resources.ResLan_SimplifiedChinese = '簡體中文';
#         Resources.ResLan_20170006 = '文檔原文';
#         Resources.ResLan_20170051 = '無目錄資料';
#         Resources.ResLan_20170016 = '分享';
#         Resources.ResLan_Author = '作者';
#         Resources.ResLan_20170052 = '原文作者';
#         Resources.ResLan_20170053 = '譯者';
#         Resources.ResLan_20170054 = '書系';
#         Resources.ResLan_Press = '出版社';
#         Resources.ResLan_20170055 = '出版日期';
#         Resources.ResLan_20170056 = '商品語言';
#         Resources.ResLan_20170057 = '定價';
#         Resources.ResLan_20170058 = '優惠價';
#         Resources.ResLan_Yuan = '元';
#         Resources.ResLan_20170061 = '折';
#         Resources.ResLan_20170008 = '買書去';
#         Resources.ResLan_20170013 = '內容簡介';
#         Resources.ResLan_20170059 = '作者介紹';
#         Resources.ResLan_20170060 = '目錄';
#         Resources.ResLan_20170082 = '確認匯入工具集';
#         Resources.ResLan_20170140 = '檔案匯入處理中，請稍後';
#         Resources.ResLan_20170147 = '您好，由於系統流量較為壅塞，為判斷用戶端為正常使用，輸入驗證碼後，請增加勾選我不是機器人選項，即可下載全文，感謝您的支持與配合。';
#
#         //_Layout_BlockUICustomSetting 定義黑屏timeout就unblock的時間與訊息
#         blockTimeoutMsg = Resources.ResLan_QueryResultsOver;
#
#         _Layout_Initialization('Airiti Library華藝線上圖書館');
#         _Layout_GoogleAnalysis();
#         _Layout_追蹤預刊和PeRT();
#
#         //紙本書的詳目頁收合
#         $('.closevsshow_div').live('click', function () {
#           var cosName = $('.browser_info_detail');
#           if (cosName.css('display') == 'block') {
#             cosName.hide();
#             $(".book_browser_all>div").addClass('show_active');
#             $(this).html("<a class='closevsshow_down' ></a>");
#
#           } else {
#             cosName.show();
#             $(".book_browser_all>div").removeClass('show_active');
#             $(this).html("<a class='closevsshow_up' ></a>");
#           }
#         });
#
#         //facebook註冊
#         (function (d, s, id) {
#           var js,
#               fjs = d.getElementsByTagName(s)[0];
#           if (d.getElementById(id)) return;
#           js = d.createElement(s);
#           js.id = id;
#           js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.9&appId=308725582894777";
#           fjs.parentNode.insertBefore(js, fjs);
#         }(document, 'script', 'facebook-jssdk'));
#
#         //大數據分析
#         (function (h, o, t, j, a, r) {
#           h.hj = h.hj || function () { (h.hj.q = h.hj.q || []).push(arguments) };
#           h._hjSettings = { hjid: 1034511, hjsv: 6 };
#           a = o.getElementsByTagName('head')[0];
#           r = o.createElement('script'); r.async = 1;
#           r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#           a.appendChild(r);
#         })(window, document, 'https://static.hotjar.com/c/hotjar-', '.js?sv=');
#       } catch (e) {
#       }
#     });
#   </script>
#
#
# </head>
# <body>
# <form action="/" id="__AjaxAntiForgeryForm" method="post"><input name="__RequestVerificationToken" type="hidden" value="Au8VfFamQD5eOFDRX8lYSJZo7QKCvrL8WY5HKo-xJ7t_dVAX-Mib-KEx3r7RzUmMldqIg12l-GOxLJjuoFoeS2w6DX82NCTCkCpkuV3uOOc1" /></form>  <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-KH8DKN2" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#   <div class="main">
#     <div class="top">
#       <div class="left">
#       </div>
#       <div class="center">
#       </div>
#       <div class="right">
#       </div>
#     </div>
#     <div class="center">
#
#       <div class="header">
#
#
#
# <script language="javascript" type="text/javascript">
#   function _Head_Go() {
#     window.open("/LoginFromAiriti.aspx");
#     //window.open("LoginFromAiriti.html?airiti_account=Sam&email=champiyen@gmail.com&userDisplay=champiyen@gmail.com");
#     //window.open("http://60.199.250.238:8080/AiritiPlatform/LoginFromAiriti?airiti_account=Sam&email=champiyen@gmail.com&userDisplay=champiyen@gmail.com");
#   }
#
#   $(document).ready(function () {
#     try {
#       Resources.ResLan_RecordsShowOnly = '團體客戶下載記錄僅呈現近三個月的下載記錄，若須完整使用記錄，請洽華藝業務同仁！';
#       Resources.ResLan_ThereAreArticlesIn = '購物清單內還有文章,是否要登出?';
#       Resources.ResLan_EnterEmail = '請輸入Email';
#       Resources.ResLan_EmailFormatIs = 'Email格式不對，Email的格式如：name@address.com';
#       Resources.ResLan_Korean1 = '韓國語';
#       Resources.ResLan_A001 = '敬愛的讀者您好，本站台服務暫時不對中國大陸地區的讀者開放，請連線至 臺灣文獻數據庫 http://airitilibrary.cn/ 使用，以保障您的權益。';
#       Resources.ResLan_CommaFull = '，';
#       Resources.ResLan_Culture = 'zh-TW';
#       //依LocationID呈現提示視窗語系 start
#
#       Resources.ResLan_Bonus_0001 = '親愛的';
#       Resources.ResLan_Bonus_0002 = '感謝您對《airiti Library華藝線上圖書館》長久以來的支持。為了擴大消費回饋，《airiti Library華藝線上圖書館》將於 2016/07/01 調整點數儲值消費方案，讓您購買每一項儲值卡套裝都享有免費的紅利贈點體驗！';
#       Resources.ResLan_Bonus_0003 = '同時，消費新制還能讓您優先利用紅利體驗點數！未來您在《airiti Library 華藝線上圖書館》使用點數購買文章時，將「優先」扣除贈送給您的免費紅利點數，確保紅利點數不過期。';
#       Resources.ResLan_Bonus_0004 = '想瞭解更多消費新制優惠，請見《';
#       Resources.ResLan_Bonus_0005 = '點數儲值消費方案全新推出';
#       Resources.ResLan_Bonus_0006 = '》。';
#       Resources.ResLan_Bonus_0007 = 'OK，我知道了';
#       Resources.ResLan_Bonus_0008 = '確認';
#       Resources.ResLan_Bonus_0009 = '資料更新成功';
#       Resources.ResLan_Bonus_0022 = '提醒您：您的紅利點數即將到期，請至「個人化服務」之「點數儲值紀錄」查詢您的紅利點數到期日。';
#       Resources.ResLan_Bonus_0023 = '不再顯示';
#       Resources.ResLan_Bonus_0032 = '向您正式宣布，《airiti Library華藝線上圖書館》已於 2016/07/01 調整點數儲值消費方案！';
#       Resources.ResLan_Bonus_0033 = '現在，每一項儲值卡套裝都享有免費的紅利贈點體驗。同時，消費新制還能讓您優先利用紅利點數！想瞭解更多消費新制優惠，請見《';
#       Resources.ResLan_Bonus_0034 = '點數儲值消費方案全新推出';
#       Resources.ResLan_Bonus_0035 = '，';
#
#       Resources.ResLan_20170080 = '個人化研究工具集';
#       Resources.ResLan_20170081 = '匯入工具集';
#       Resources.ResLan_20170082 = '確認匯入工具集';
#       Resources.ResLan_20170083 = '已匯入至個人化研究工具集';
#       Resources.ResLan_20170084 = '開啟工具集';
#       Resources.ResLan_20170085 = '很抱歉，您的B2C點數不足，無法導入工具集，請重新儲值後使用，謝謝';
#       Resources.ResLan_20170086 = '親愛的';
#       Resources.ResLan_20170087 = '向您正式宣布，《airiti Library華藝線上圖書館-個人化研究工具集》已於';
#       Resources.ResLan_20170088 = '正式上線！';
#       Resources.ResLan_20170089 = '您可於登入後，於個人化服務選單連線至';
#       Resources.ResLan_20170090 = '，或是檢索文章後，直接導入';
#       Resources.ResLan_20170091 = 'OK，我知道了';
#       //依LocationID呈現提示視窗語系 end
#
#
#       _Head_Initialization();
#
#       //$("#selectLanguage option[value=" + 'zh-TW' + "]").attr('selected', 'selected');
#
#       //$('#divLanguage a').click(function () {
#       $('#selectLanguage').change(function () {
#         //var thisCul = $($(this)[0]).attr('key');
#         var thisCul = $($(this)[0]).attr('value');
#         _Layout_BlockUICustomSetting(function () {
#           var action = '/AL' + '/SetCulture';
#           _Layout_LoadBody(action, 'POST', { culture: thisCul, processUrl: window.location.href });
#         });
#         //$('#selectLanguage').val(thisCul);
#         //$("#selectLanguage option[value="+thisCul+"]").attr('selected', 'selected');
#       });
#       //不做 Prepare 動作，減少伺服器負荷
#       //_Head_PrepareMemberJoin();
#       //有帳密登入後, 導向加入會員, 要重刷頁面, 因為在thickbox內生成div內容難以控制, 複雜性太高, 故重刷後在進加入會員
#       var haveLoginDataToMemberJoin = ''.toString().toLowerCase();
#       if (haveLoginDataToMemberJoin === 'true') {
#         _Head_GetMemberJoin();
#       }
#
#       //var isShowBonusMsg = ''.toString().toLowerCase();
#       var 是否秀個人化研究工具集提示 = ''.toString().toLowerCase();
#       var isShowBonusExpireMsg = ''.toString().toLowerCase();
#       var isShowAfterBonusMsg = ''.toString().toLowerCase();
#       var isPleaseLogin = ''.toString().toLowerCase();
#
#       //debugger;
#
#       if (是否秀個人化研究工具集提示 === 'true') {
#         _Head_個人化研究工具集提示視窗('');
#       }
#       if (isShowBonusExpireMsg === 'true') {
#         _Head_CreateBonusExpireText();
#       }
#       if (isShowAfterBonusMsg === 'true') {
#         _Head_CreateAfterBonusText('B2B', '', '01');
#       }
#       //未登入, 在url貼上購物車連結, 讓它點選登入
#       if (isPleaseLogin === 'true') {
#         tb_show('', '/Member/alMemberLogin?keepThis=true&TB_iframe=true&height=1000&width=1500', false); //跳出登入
#       }
#     } catch (e) {
#     }
#   });
# </script>
#
# <div class="top">
#   <div class="logo">
#     <a href="/Home/Index">
#       <img src="/Content/images/logo.jpg" alt="logo" />
#     </a>
#   </div>
#   <div class="title">
#     <div id="divLanguage" class="divLanguage">
#
#       <select id="selectLanguage">
#         <option>Language</option>
#         <option value="en-US">English</option>
#         <option value="zh-TW">繁體中文</option>
#         <option value="zh-CN">简体中文</option>
#         <option value="ko-KR">한국어</option>
#       </select>
#     </div>
#   </div>
# </div>
# <div class="userList">
#   <font class="red">南華大學，您好！</font>
#
# </div>
# <input type="text" id="txtCurrentPoint" style="display:none;" />
# <div class="middle">
#   <div class="blueLeft">
#   </div>
#   <div class="blueCenter">
#           <a href="/Search/alJnlbrowse" onclick="Share_ShowMouseButton(function(){_Layout_LoadBody('/Search/alJnlbrowse');},this); return false;">瀏覽</a>
#
#
#     <a href="/Search/alGCS000003" onclick="Share_ShowMouseButton(function(){_Layout_LoadBody('/Search/alGCS000003');},this); return false;">進階檢索</a>
#
#
#     <!-- 開啟購物車功能 阿吉-->
#     <a href="javascript:_Head_GoShoppingCar('','01');">儲值&amp;購物車</a>
#   </div>
#   <div class="blueRight">
#   </div>
#   <div class="grayLeft">
#     <div class="user">
#       <div class="link">
#
#         <ul class="navPersonalized">
#           <li><a class="thickbox" href="/Member/alMemberLogin?keepThis=true&TB_iframe=true&height=1000&width=1500">登入</a>│</li>
#           <li><a href="javascript:_Head_GetMemberJoin();" >加入會員</a>│</li>
#           <li><a href="javascript:;" onclick="_Head_GoShoppingCar();">購買點數</a>│</li>
#           <li>
#             <a href="javascript:;">
#               個人化服務
#               <img src="/Content/images/personalDropDown.gif" alt="" />
#             </a>
#             │
#             <ul class="subnav">
#               <li><a class="thickbox" href="/Member/alMemberLogin?keepThis=true&TB_iframe=true&height=1000&width=1500">會員登入</a></li>
#
#               <li><a href="javascript:_Layout_LoadBody('/Member/ReSendAuthLetter','GET');" >重發認證信</a></li>
#               <li><a href="javascript:_Layout_LoadBody('/Member/alForget','GET');" >忘記帳號密碼</a></li>
#               <li>
#                 <a href="javascript:_Head_GoBonus();">序號加值</a>
#               </li>
#               <li>
#
#
#                 <a href="/Home/Login_PPChecktoal" target="_blank">文獻相似度檢測服務</a>
#               </li>
#               <li>
#                 <a href="javascript:_Layout_LoadBody('/Member/alHistory_1');">查詢歷史</a>
#               </li>
#
#
#
#
#
#
#             </ul>
#           </li>
#           <li>
#             <a href="javascript:_Layout_LoadBody('/Home/Service1PostNoGet');">客服中心</a>
#             │
#           </li>
#           <li>
#             <a href="javascript:_Layout_LoadBody('/Home/Userguide');">使用說明</a>
#             │
#           </li>
#           <li>
#             <a href="javascript:_Layout_ShowHideLayers('sitemapNew','','show');" class="info_sub">
#               網站地圖
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </div>
# </div>
#
# <div id="sitemapNew">
#   <table border="0" cellpadding="0" cellspacing="0">
#     <tr>
#       <td colspan="2" align="right" class="bar">
#         <a href="javascript:_Layout_ShowHideLayers('sitemapNew','','hide');">
#           關閉
#           <img src="/Content/images/icon_x.gif" alt="close" width="18" height="17" align="absmiddle" />
#         </a>
#       </td>
#     </tr>
#     <tr>
#       <td valign="top">
#         <div class="title">
#           查詢
#         </div>
#         <ul>
#           <li>
#             <a href="javascript:;">簡易查詢</a>
#           </li>
#           <li>
#             <a href="javascript:_Layout_ShowHideLayers(&#39;sitemapNew&#39;,&#39;&#39;,&#39;hide&#39;); _Layout_LoadBody('/Search/alGCS000003');">進階檢索</a>
#           </li>
#           <li>
#             <a href="javascript:;">出版品查詢</a>
#           </li>
#         </ul>
#       </td>
#       <td rowspan="3" valign="top">
#         <div class="title">
#           個人化服務
#         </div>
#         <ul>
#           <li><a class="thickbox" href="/Member/alMemberLogin?keepThis=true&TB_iframe=true&height=1000&width=1500">會員登入</a></li>
#           <li>
#             <a href="javascript:_Layout_ShowHideLayers(&#39;sitemapNew&#39;,&#39;&#39;,&#39;hide&#39;); _Layout_LoadBody('/Member/alHistory_1');">查詢歷史</a>
#           </li>
#
#           <li>
#             <a href="javascript:_Layout_ShowHideLayers(&#39;sitemapNew&#39;,&#39;&#39;,&#39;hide&#39;); _Head_GoBonus();">序號加值</a>
#           </li>
#           <li>
#
#
#             <a href="/Home/Login_PPChecktoal" target="_blank">文獻相似度檢測服務</a>
#           </li>
#
#         </ul>
#       </td>
#     </tr>
#     <tr>
#       <td valign="top">
#         <div class="title">
#           瀏覽
#         </div>
#         <ul>
#                       <li>
#               <a href="javascript:_Layout_ShowHideLayers(&#39;sitemapNew&#39;,&#39;&#39;,&#39;hide&#39;); _Layout_LoadBody('/Search/alThesisbrowse');">學位論文校院瀏覽</a>
#             </li>
#             <li>
#               <a href="javascript:_Layout_ShowHideLayers(&#39;sitemapNew&#39;,&#39;&#39;,&#39;hide&#39;); _Layout_BlockUICustomSetting(function(){_Layout_PjaxToOtherPageTypeFirstIDSecondID('/Search/alThesisbrowse','PhoneticColleges');});">
#                 學位論文拼音瀏覽
#               </a>
#             </li>
#                       <li>
#               <a href="javascript:_Layout_ShowHideLayers(&#39;sitemapNew&#39;,&#39;&#39;,&#39;hide&#39;); _Layout_LoadBody('/Search/alConfbrowse');">會議論文主題瀏覽</a>
#             </li>
#             <li>
#               <a href="javascript:_Layout_ShowHideLayers(&#39;sitemapNew&#39;,&#39;&#39;,&#39;hide&#39;); _Layout_BlockUICustomSetting(function(){_Layout_PjaxToOtherPageTypeFirstIDSecondID('/Search/alConfbrowse','PublishedsSubject');});">
#                 會議論文出版單位瀏覽
#               </a>
#             </li>
#             <li>
#               <a href="javascript:_Layout_ShowHideLayers(&#39;sitemapNew&#39;,&#39;&#39;,&#39;hide&#39;); _Layout_BlockUICustomSetting(function(){_Layout_PjaxToOtherPageTypeFirstIDSecondID('/Search/alConfbrowse','PhoneticsSubject');});">
#                 會議論文拼音瀏覽
#               </a>
#             </li>
#                   </ul>
#       </td>
#     </tr>
#     <tr>
#       <td valign="top">
#         <div class="title">
#           客戶服務
#         </div>
#         <ul>
#           <li>
#             <a href="javascript:_Layout_ShowHideLayers(&#39;sitemapNew&#39;,&#39;&#39;,&#39;hide&#39;); _Layout_LoadBody('/Home/Cooperation');">授權華藝</a>
#           </li>
#           <li>
#             <a href="javascript:_Layout_ShowHideLayers(&#39;sitemapNew&#39;,&#39;&#39;,&#39;hide&#39;); _Layout_LoadBody('/Home/Promote');">推薦刊物</a>
#           </li>
#         </ul>
#       </td>
#     </tr>
#   </table>
# </div>
#
#
# <div id="QueryHistorical">
#   <div class="bar">
#     <a href="javascript:_Layout_ShowHideLayers('QueryHistorical','','hide')">
#       關閉
#       <img src="/Content/images/icon_x.gif" alt="close" width="18" height="17" align="absmiddle" />
#     </a>
#   </div>
#   <table width="420" cellspacing="0" cellpadding="0">
#     <tr class="title">
#       <td width="120" align="center">
#         <strong>查詢符號(半形)</strong>
#       </td>
#       <td width="300" align="center">
#         <strong>查詢符號意義說明</strong>
#       </td>
#     </tr>
#     <tr>
#       <td align="center">
#         <strong>空格</strong>
#       </td>
#       <td>
#         表示為「AND」兩個查詢詞之交集
#       </td>
#     </tr>
#     <tr>
#       <td align="center">
#         <strong>
#           雙引號
#           (
#           &quot;
#           &quot;
#           )
#         </strong>
#       </td>
#       <td>
#         片語以雙引號標示開始及結束，而且只尋找出現順序相同的字詞，例
#         ：
#         &quot;
#         image process
#         &quot;
#       </td>
#     </tr>
#     <tr>
#       <td align="center">
#         <strong>?</strong>
#       </td>
#       <td>
#         表示一個字母切截，輸入兩個?表兩個字母，依此類推，例：輸入「Appl?」，查得結果應為appl
#         <u>e</u>
#         ,
#         appl
#         <u>y</u>
#         …
#         (
#         常用於英文字查詢
#         )
#       </td>
#     </tr>
#     <tr>
#       <td align="center">
#         <strong>*</strong>
#       </td>
#       <td>
#         表示不限字母切截，由0~n. 例：輸入「appl*」，查得結果應為appl
#         <u>e</u>
#         ,
#         appl
#         <u>es</u>
#         ,
#         appl
#         <u>y</u>
#         ,
#         appl
#         <u>ied</u>
#         ,
#         appl
#         <u>ication</u>
#         …
#         (
#         常用於英文字查詢
#         )
#       </td>
#     </tr>
#     <tr>
#       <td height="59" align="center">
#         <strong>AND、OR、NOT</strong>
#       </td>
#       <td>
#         <p>
#           布林邏輯組合關鍵字，用來擴大或縮小查詢範圍的技巧。
#           <br />
#           (1) AND
#           ：縮小查詢範圍
#           <br />
#           (2) OR
#           ：擴大查詢範圍 (3) NOT：排除不相關的範圍
#         </p>
#       </td>
#     </tr>
#   </table>
# </div>
#
#
#
# <script language="javascript" type="text/javascript" >
# 	$(document).ready(function () {
# 		try {
# 			Resources.ResLan_AllFields = '所有欄位';
# 			Resources.ResLan_PublicationName = '出版品名稱';
# 			Resources.ResLan_NameOfPublication = '出版品單位名稱';
# 			Resources.ResLan_TitleKeywordsAbstract = '篇名.關鍵字.摘要';
# 			Resources.ResLan_Author = '作者';
# 			Resources.ResLan_TitleBookTitleDepartment = '刊名/書名/論文發表系所';
# 		  Resources.ResLan_PleaseEnterSearch = '請輸入查詢條件';
# 		  Resources.ResLan_A115 = '檢索詞限制在200個字以內，請修正檢索詞後重新檢索，謝謝！';
#
# 			_Search_Initialization();
# 		} catch (e) {
# 		}
# 	});
# </script>
#
# <div class="down">
# 	<div class="top">
# 	</div>
# 	<div class="search">
# 		<form action="#" method="post" name="SearchForm" id="SearchForm" onkeypress="_Search_KeyPressFunction(event);">
# 			<div class="left1">
# 			</div>
# 			<div class="left" id="searchBold">
# 				│
# 				<a id="article" class="bold" href="javascript:;">文章</a>
# 				│
# 				<a id="producedText" href="javascript:;">出版品</a>
# 				│
# 			</div>
# 			<div class="input" id="a1">
# 				<div class="left">
# 				</div>
# 				<div class="center">
# 					<div class="center">
# 						<input id="ArticlesViewModel_SearchField" name="ArticlesViewModel.SearchField" onblur="_Search_CheckSearchFildOnblurState(this);" onkeydown="$(this).css('color','#000000');" onfocus="if(this.value=='所有欄位'){this.value='';}" type="text" class="inputImg" value="所有欄位" />
# 						<input id="PublicationsViewModel_SearchField" name="PublicationsViewModel.SearchField" onblur="_Search_CheckSearchFildOnblurState(this);" onfocus="if(this.value=='所有欄位'){this.value='';}" type="text" onkeydown="$(this).css('color','#000000');" class="inputImg" value="所有欄位" style="display: none" />
# 					</div>
# 				</div>
# 				<a id="Search" href="javascript:;" onclick="_Layout_BlockUICustomSetting(function(){_Search_Onclick();});">
# 					<img src="/Content/images/searchBotton.jpg" alt="搜索" id="images1" onmouseover="_Layout_SwapImage('images1','','/Content/images/searchBottonHover.jpg',1);" onmouseout="_Layout_SwapImgRestore();" />
# 				</a>
# 				<ul id="nav-one" class="nav">
# 					<li>
# 						<a href="javascript:;">
# 							<img src="/Content/images_tw/moreBotton.png" alt="更多選項" id="images2" onmouseover="_Layout_SwapImage('images2','','/Content/images_tw/moreBottonHover.png',1);" onmouseout="_Layout_SwapImgRestore();" />
# 						</a>
#
# 						<ul class="subnav">
# 							<li class="padd">更多查詢條件</li>
# 							<li>
# 								<input class="long" id="PublicationsViewModel_SearchField1" name="PublicationsViewModel.SearchField" onblur="if(this.value==''){this.value='所有欄位'; $(this).css('color','#8a8a8a');}" onfocus="if(this.value=='所有欄位'){this.value='';}" type="text" onkeydown="$(this).css('color','#000000');" value="所有欄位" />
# 							</li>
# 							<li class="article1">
# 								<input class="small" id="ArticlesViewModel_TitleKeywordsAbstract" name="ArticlesViewModel.TitleKeywordsAbstract" onblur="if(this.value==''){this.value='篇名.關鍵字.摘要'; $(this).css('color','#8a8a8a');}" onfocus="if(this.value=='篇名.關鍵字.摘要'){this.value='';}" onkeydown="$(this).css('color','#000000');" type="text" value="篇名.關鍵字.摘要" />
# 								<span></span>
# 								<input class="small" id="ArticlesViewModel_Author" name="ArticlesViewModel.Author" onblur="if(this.value==''){this.value='作者'; $(this).css('color','#8a8a8a');}" onfocus="if(this.value=='作者'){this.value='';}" type="text" onkeydown="$(this).css('color','#000000');" value="作者" />
# 							</li>
# 							<li class="article1">
# 								<input class="long" id="ArticlesViewModel_JournalBookDepartment" name="ArticlesViewModel.JournalBookDepartment" onblur="if(this.value==''){this.value='刊名/書名/論文發表系所'; $(this).css('color','#8a8a8a');}" onfocus="if(this.value=='刊名/書名/論文發表系所'){this.value='';}" onkeydown="$(this).css('color','#000000');" value="刊名/書名/論文發表系所" type="text" />
# 							</li>
# 							<li class="article1">
# 								<input class="small" id="ArticlesViewModel_DOI" name="ArticlesViewModel.DOI" onblur="if(this.value==''){this.value='DOI'; $(this).css('color','#8a8a8a');}" onfocus="if(this.value=='DOI'){this.value='';}" onkeydown="$(this).css('color','#000000');" type="text" value="DOI" style="color: rgb(138, 138, 138);">
# 								<span></span>
# 							</li>
# 							<li class="producedText1">
# 								<input class="small" id="PublicationsViewModel_PublicationName" name="PublicationsViewModel.PublicationName" onblur="if(this.value==''){this.value='出版品名稱';}" onfocus="if(this.value=='出版品名稱'){this.value='';}" type="text" value="出版品名稱" />
# 								<span></span>
# 								<input class="small" id="PublicationsViewModel_ISSN" name="PublicationsViewModel.ISSN" onblur="if(this.value==''){this.value='ISSN 1817-406X';}" onfocus="if(this.value=='ISSN 1817-406X'){this.value='';}" type="text" value="ISSN 1817-406X" />
# 							</li>
# 							<li class="producedText1">
# 								<input class="long" id="PublicationsViewModel_PublicationUnitName" name="PublicationsViewModel.PublicationUnitName" onblur="if(this.value==''){this.value='出版品單位名稱';}" onfocus="if(this.value=='出版品單位名稱'){this.value='';}" type="text" value="出版品單位名稱" />
# 							</li>
# 							<li class="producedText1">
# 								<input class="long" id="PublicationsViewModel_DOI" name="PublicationsViewModel.DOI" onblur="if(this.value==''){this.value='DOI'; $(this).css('color','#8a8a8a');}" onfocus="if(this.value=='DOI'){this.value='';}" onkeydown="$(this).css('color','#000000');" type="text" value="DOI" style="color: rgb(138, 138, 138);">
# 							</li>
# 							<li class="last">
# 								出版地區
# 								<div id="ArticleArea">
#
# 									<input id="ArticlesViewModel_ArticleArea_Taiwan" name="ArticlesViewModel.ArticleArea_Taiwan" type="checkbox">台灣
# 									<input id="ArticlesViewModel_ArticleArea_ChinaHongKongMacao" name="ArticlesViewModel.ArticleArea_ChinaHongKongMacao" type="checkbox">中國大陸(含港澳)
# 									<input id="ArticlesViewModel_ArticleArea_American" name="ArticlesViewModel.ArticleArea_American" type="checkbox">美國
# 									<input id="ArticlesViewModel_ArticleArea_Other" name="ArticlesViewModel.ArticleArea_Other" type="checkbox">其他地區
# 								</div>
# 								<div id="PublicationArea">
#
# 									<input id="PublicationsViewModel_PublicationArea_Taiwan" name="PublicationsViewModel.PublicationArea_Taiwan" type="checkbox">台灣
# 									<input id="PublicationsViewModel_PublicationArea_ChinaHongKongMacao" name="PublicationsViewModel.PublicationArea_ChinaHongKongMacao" type="checkbox">中國大陸(含港澳)
# 									<input id="PublicationsViewModel_PublicationArea_American" name="PublicationsViewModel.PublicationArea_American" type="checkbox">美國
# 									<input id="PublicationsViewModel_PublicationArea_Other" name="PublicationsViewModel.PublicationArea_Other" type="checkbox" value="true">其他地區
# 								</div>
# 							</li>
# 						</ul>
# 					</li>
# 				</ul>
# 			</div>
# 			<div class="right">
# 				<a onclick="_Layout_ShowHideLayers('QueryHistorical', '', 'show');">
# 					<img class="hand" src="/Content/images/questionMark.gif" alt="?" />
# 				</a>
# 				<a class="up" href="javascript:;" onclick="_Layout_LoadBody('/Member/alHistory_1');">查詢歷史</a>
# 			</div>
# 		</form>
# 	</div>
#
#
# </div>
#       </div>
#
#
#       <div id="maincontent" class="content">
#         <script src="/Scripts/activebar2?v=NHTirMXktEGnzpd6Rg-HHRx-iM7mwcwwbexGZRWPxG81"></script>
#
#
#
#
# <script language="javascript" type="text/javascript">
# 	Index_CheckBrowserAndAlert();
# 	//維護公告, 維護再打開
# 	//Index_MaintenanceNotice();
#
# 	//曝光區5秒輪播功能
# 	var currentIdx = -1;
# 	var speed = 5000;
# 	var imgIdx = -1;
# 	var timer;
#
# 	$(document).ready(function () {
# 		var _showTab = 0;
# 		var $tab = $(this);
# 		var $defaultLi = $('ul#indexCarousel li').eq(_showTab).addClass('middleMenuButtonFocus');
# 	  try {
#       //關閉停機公告  阿吉
# 	    //tb_show('', '/Content/html/announce20190201.html?keepThis=true&TB_iframe=true&height=1000&width=1400&scrolling=no', false); //跳出系統下架公告
#
# 			Resources.ResLan_WeRecommendThat = '建議您使用新版瀏覽器！';
# 			Resources.ResLan_RemindYouThat = '提醒您，舊版的瀏覽器會造成網頁錯誤。請使用新版瀏覽器以獲得最佳瀏覽效果！免費下載更新更好的瀏覽器：';
#
# 			$($defaultLi.find('a').attr('key')).siblings().hide();
# 			$('ul#indexCarousel li', $tab).find('a').focus(function () {
# 				this.blur();
# 			});
#
# 			Index_AutoShow();
#
# 			if ('false' === 'true') {
# 				alert('');
# 			}
#
# 	    if ('') {
# 		    _Head_GetMemberJoin();
# 	    }
#
# 	    //大數據分析
# 	    (function (h, o, t, j, a, r) {
# 	      h.hj = h.hj || function () { (h.hj.q = h.hj.q || []).push(arguments) };
# 	      h._hjSettings = { hjid: 1032979, hjsv: 6 };
# 	      a = o.getElementsByTagName('head')[0];
# 	      r = o.createElement('script'); r.async = 1;
# 	      r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
# 	      a.appendChild(r);
# 	    })(window, document, 'https://static.hotjar.com/c/hotjar-', '.js?sv=');
# 		} catch (e) {
# 		}
# 	});
# </script>
#
# <div class="leftIndex">
# 	<div class="top_bannernews">
#
# <script language="javascript" type="text/javascript">
#   //曝光區5秒輪播功能
#   var bg_CurrentIdx = -1;
#   var bg_Speed = 5000;
#   var bg_ImgIdx = -1;
#   var bg_Timer;
#
#   $(document).ready(function () {
#     var $tab = $(this);
#     var $defaultLi = $('ul#bg_ul li').eq(0).addClass('activehere');
#     try {
#       //$(window).load(function () {
#       //});
#
#       $('#bg_tabA4').show();
#       $($defaultLi.find('a').attr('key')).siblings().hide();
#       $('ul#bg_ul li', $tab).find('a').focus(function () {
#         this.blur();
#       });
#       //暫時先不輪播, 先弄其他, 最後再來這裡找
#       BannerGraph_AutoShow();
#
#       //$('#bg_tabA1').unbind("click").bind("click", function (event) {
#       //  window.open('https://goo.gl/forms/edP7W67LV6A9CcU33');
#       //  window.open('/EDM/20170825/106原住民智慧財產權法_n0825.pdf');
#       //});
#     } catch (e) {
#     }
#   });
# </script>
# <ul class="tab_button" id="bg_ul">
# 	<li key="#bg_tabA1" onmouseover="BannerGraph_Tabmouseover();" onmouseout="BannerGraph_Tabmouseout();">
#     <div>
#       <a href="javascript:;" key="#bg_tabA1" onclick="BannerGraph_Tabclick(this);">1</a>
#     </div>
#   </li>
# 	<li key="#bg_tabA2" onmouseover="BannerGraph_Tabmouseover();" onmouseout="BannerGraph_Tabmouseout();">
# 		<div>
# 			<a href="javascript:;" key="#bg_tabA2" onclick="BannerGraph_Tabclick(this);">2</a>
# 		</div>
# 	</li>
#   <li key="#bg_tabA3" onmouseover="BannerGraph_Tabmouseover();" onmouseout="BannerGraph_Tabmouseout();">
#     <div>
#       <a href="javascript:;" key="#bg_tabA3" onclick="BannerGraph_Tabclick(this);">3</a>
#     </div>
#   </li>
# 	<li key="#bg_tabA4" onmouseover="BannerGraph_Tabmouseover();" onmouseout="BannerGraph_Tabmouseout();">
# 		<div>
# 			<a href="javascript:;" key="#bg_tabA4" onclick="BannerGraph_Tabclick(this);">4</a>
# 		</div>
# 	</li>
#   <li key="#bg_tabA5" onmouseover="BannerGraph_Tabmouseover();" onmouseout="BannerGraph_Tabmouseout();">
#     <div>
#       <a href="javascript:;" key="#bg_tabA5" onclick="BannerGraph_Tabclick(this);">5</a>
#     </div>
#   </li>
# </ul>
#
# <div class="top_banner" id="bg_container">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <div class="tab_here" id="bg_tabA1" style="display: none;">
#
#
#
#
#     <a href="/EDM/20181105/20181029.html" target="_blank">
#       <img src="/EDM/20181105/743x138.jpg" border="0" style="width:743px;height:138px" />
#     </a>
#   </div>
#
#
#
#
#
#   <div class="tab_here" id="bg_tabA2" style="display: none;">
#
#
#
#
#     <a href="https://www.airitiorcid.com" target="_blank">
#       <img src="/EDM/BannerGraph/orvid.png" border="0" style="width:743px;height:138px" />
#     </a>
#   </div>
#
#
#   <div class="tab_here" id="bg_tabA3" style="display: none;">
#     <a href="https://goo.gl/LnE6Su" target="_blank">
#       <img src="/EDM/BannerGraph/20190318_3.jpg" border="0" style="width:743px;height:138px" />
#     </a>
#   </div>
#
#
#   <div class="tab_here" id="bg_tabA4" style="display: none;">
#     <a href="https://goo.gl/X8h9Az" target="_blank">
#       <img src="/EDM/BannerGraph/20190318_4.jpg" border="0" style="width:743px;height:138px" />
#     </a>
#   </div>
#
#
# 	<div class="tab_here" id="bg_tabA5" style="display: none;">
#       <a href="https://goo.gl/XqKGXB" target="_blank">
#         <img src="/EDM/BannerGraph/20190318_5.jpg" border="0" style="width:743px;height:138px" />
#       </a>
# 	</div>
#
#
#
#
#
#
#
#
#
#
#
#
# </div>
# 	</div>
# 	<div class="middleMenu">
# 		<div class="down">
# 			<div class="navigation_new">
#
#
#
#
#
# <div class="newsall_tab" id="news">
#   <ul class="newstt" id="indexCarousel">
#     <li class="on" key="#tabA" onmouseover="Index_Tabclick(this); Index_Tabmouseover();" onmouseout="Index_Tabmouseout();">
#       <div class="which_one">
#         <a href="javascript:;" key="#tabA" onclick="Index_Tabclick(this);">推薦閱讀</a>
#       </div>
#     </li>
#     <li class="off" key="#tabB" onmouseover="Index_Tabclick(this); Index_Tabmouseover();" onmouseout="Index_Tabmouseout();">
#       <div class="which_one">
#         <a href="javascript:;" key="#tabB" onclick="Index_Tabclick(this);">預刊文章</a>
#       </div>
#     </li>
#     <li class="off" key="#tabC" onmouseover="Index_Tabclick(this); Index_Tabmouseover();" onmouseout="Index_Tabmouseout();">
#       <div class="which_one">
#         <a href="javascript:;" key="#tabC" onclick="Index_Tabclick(this);">最新上線</a>
#       </div>
#     </li>
#     <li class="off" key="#tabD" onmouseover="Index_Tabclick(this); Index_Tabmouseover();" onmouseout="Index_Tabmouseout();">
#       <div class="which_one">
#         <a href="javascript:;" key="#tabD" onclick="Index_Tabclick(this);">精選期刊</a>
#       </div>
#     </li>
#     <li class="off" key="#tabE" onmouseover="Index_Tabclick(this); Index_Tabmouseover();" onmouseout="Index_Tabmouseout();">
#       <div class="which_one">
#         <a href="javascript:;" key="#tabE" onclick="Index_Tabclick(this);">學界快訊</a>
#       </div>
#     </li>
#   </ul>
# </div>
# <div class="newstt_content" id="CarouselTab_container">
#   <div class="l_wen_div_all" id="tabA">
#     <div class="l_wen_div">
#             <div class="l_wen_div_img">
#               <img src="http://hyint.nhu.edu.tw:2053//jnltitledo/10267301-c.jpg" />
#             </div>
#             <div class="l_wen l_wen_w1">
#               <div class="l_wentitle">
#                 <a href="/Publication/Index/10267301-201706-201709010002-201709010002-336-345" onclick="Share_ShowMouseButton(function(){_Layout_BlockUICustomSetting(function(){_Layout_PjaxToOtherPageTypeFirstIDSecondID('/Publication/Index','','10267301-201706-201709010002-201709010002-336-345');});},this); return false;">一位肺炎併急性呼吸衰竭個案之急診護理經驗</a>
#               </div>
#               <div>
#                 <ul class="content_a">
#                   <li>
#                     <a href="javascript:_Layout_BlockUICustomSetting(function(){_Layout_KeyWordSearch('劉心瑋');});">劉心瑋(Hsing-Wei Liu);陳淑賢(Sue-Hsien Chen);謝芳貴(Fang-Kuei Hsien)</a>
#                     ；
#                       <a href="/Publication/PublicationIndex/10267301?IssueID=201709010002" onclick="Share_ShowMouseButton(function(){_Layout_BlockUICustomSetting(function(){_Layout_PjaxToOtherPageTypeFirstIDSecondID('/Publication/PublicationIndex','','10267301','201709010002');});},this); return false;">
#                         長庚護理
#                         (20170601)
#                       </a>
#                   </li>
#
#
#                 </ul>
#               </div>
#                     <div style="display:inline;">本文描述一位93歲男性罹患肺炎併急性呼吸衰竭，在面臨放置氣管內管覺得生命即將消失，考慮到氣管內管可能要長期留置，且致死亡時均無法脫離呼吸器甚至需終身臥床仰賴他人全責照顧。病人對未來無法預知結果，深度感覺生命受到嚴重威脅。2013年10月25日至10月27日的期間，筆者運用Gordon十一項功能性健康評估模式以直接會談、觀察、身體評估及病歷查閱進行評估，並且確立個案有呼吸道清除功能失效、睡眠型態紊亂及焦慮等健康問</div>
#               <div style="display:inline;color:red;">...</div>
#
#
#
#
#
#             </div>
#
#     </div>
#   </div>
#   <div class="l_wen_div_all" id="tabB">
#     <div class="l_wen_div">
#       <div class="l_wen">
#         <div class="l_wentitle">
#           <a href="#">
#             預刊文章
#             ：
#             學術資訊最前線
#             ！
#           </a>
#         </div>
#
#
#         <div class="preprint_c">
#           <div class="preprint_intro">
#             <div class="preprint_intro_t">
#               <b>
#
#                 什麼是預刊文章
#                 <span class="preprint_intro_q">？</span>
#               </b>
#             </div>
#             <div class="preprint_intro_c">
#
#               指「經同儕審核」、「期刊單位確定收稿」，但「尚未集結完本出本」的單篇期刊論文。
#             </div>
#           </div>
#           <div class="preprint_intro">
#             <div class="preprint_intro_t">
#               <b>
#
#                 預刊文章的價值
#                 <span class="preprint_intro_q">？</span>
#               </b>
#             </div>
#             <div class="preprint_intro_c">
#               <div>
#                 <div class="preprint_number">1.</div>
#                 <div class="preprint_list_c">
#
#                   加速學術傳播進程，提早接收、引用最新發表。
#                 </div>
#               </div>
#               <div>
#                 <div class="preprint_number">2.</div>
#                 <div class="preprint_list_c">
#
#                   協助投稿者找到有優先出版制度的期刊單位，即早確立學術貢獻。
#                 </div>
#               </div>
#               <div>
#                 <div class="preprint_number">3.</div>
#                 <div class="preprint_list_c">
#
#                   透過 DOI 完整追蹤論文修訂歷程。
#                 </div>
#               </div>
#             </div>
#           </div>
#           <div class="preprint_recomand">
#                 <div class="preprint_recomand_t">
#                   <b>
#
#                     推薦閱讀
#                     <span class="preprint_recomand_qq">
#
#                       ：
#                     </span>
#                   </b>
#                 </div>
#                 <div class="preprint_recomand_c">
# <a href=/Publication/PublicationIndex?PublicationID=09647058 target="_blank">Asia Pacific Journal of Clinical Nutrition</a>；<a href=/Publication/PublicationIndex?PublicationID=10152687 target="_blank">臺大文史哲學報</a>
#                 </div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
#   <div class="l_wen_div_all" id="tabC">
#     <div class="l_wen_div">
#       <div class="l_wen">
#           <div class="l_wentitle">
#
#             最新上線
#             <hr />
#           </div>
#           <div>
#             <ul class="content_a">
#                     <li>
#                       <a href="/Publication/PublicationIndex/15632555?IssueID=201902220002" onclick="Share_ShowMouseButton(function(){_Layout_BlockUICustomSetting(function(){_Layout_PjaxToOtherPageTypeFirstIDSecondID('/Publication/PublicationIndex','','15632555','201902220002');});},this); return false;">
#                         物理治療
#                         44卷1期
#                         &nbsp;
#                         &nbsp;
#                         &nbsp;
#                         &nbsp;
#                         (
#                         出刊日期(紙本)
#                         ：
#                         20190301
#                         )
#                       </a>
#                     </li>
#                     <li>
#                       <a href="/Publication/PublicationIndex/10162364?IssueID=201902230001" onclick="Share_ShowMouseButton(function(){_Layout_BlockUICustomSetting(function(){_Layout_PjaxToOtherPageTypeFirstIDSecondID('/Publication/PublicationIndex','','10162364','201902230001');});},this); return false;">
#                         Journal of Information Science and Engineering
#                         35卷2期
#                         &nbsp;
#                         &nbsp;
#                         &nbsp;
#                         &nbsp;
#                         (
#                         出刊日期(紙本)
#                         ：
#                         20190301
#                         )
#                       </a>
#                     </li>
#                     <li>
#                       <a href="/Publication/PublicationIndex/00492930?IssueID=201902130012" onclick="Share_ShowMouseButton(function(){_Layout_BlockUICustomSetting(function(){_Layout_PjaxToOtherPageTypeFirstIDSecondID('/Publication/PublicationIndex','','00492930','201902130012');});},this); return false;">
#                         Tamkang Journal of Mathematics
#                         50卷1期
#                         &nbsp;
#                         &nbsp;
#                         &nbsp;
#                         &nbsp;
#                         (
#                         出刊日期(紙本)
#                         ：
#                         20190301
#                         )
#                       </a>
#                     </li>
#                     <li>
#                       <a href="/Publication/PublicationIndex/P20161117001?IssueID=201902150007" onclick="Share_ShowMouseButton(function(){_Layout_BlockUICustomSetting(function(){_Layout_PjaxToOtherPageTypeFirstIDSecondID('/Publication/PublicationIndex','','P20161117001','201902150007');});},this); return false;">
#                         台灣原住民族研究學報
#                         9卷1期
#                         &nbsp;
#                         &nbsp;
#                         &nbsp;
#                         &nbsp;
#                         (
#                         出刊日期(紙本)
#                         ：
#                         20190301
#                         )
#                       </a>
#                     </li>
#                     <li>
#                       <a href="/Publication/PublicationIndex/10220690?IssueID=201902200002" onclick="Share_ShowMouseButton(function(){_Layout_BlockUICustomSetting(function(){_Layout_PjaxToOtherPageTypeFirstIDSecondID('/Publication/PublicationIndex','','10220690','201902200002');});},this); return false;">
#                         品質學報
#                         26卷1期
#                         &nbsp;
#                         &nbsp;
#                         &nbsp;
#                         &nbsp;
#                         (
#                         出刊日期(紙本)
#                         ：
#                         20190228
#                         )
#                       </a>
#                     </li>
#             </ul>
#
#           </div>
#
#       </div>
#     </div>
#   </div>
#   <div class="l_wen_div_all" id="tabD">
#     <div class="l_wen_div">
#
#
#       <div class="l_wen_div_img">
#         <img src="http://hyint.nhu.edu.tw:2053//jnltitledo/17272432-c.jpg" />
#       </div>
#       <div class="l_wen l_wen_w1">
#         <div class="bn_content">
#           <div class="bn_list">
#             <div class="bn_title">
#               <div>期刊名稱</div>
#               <div class="bn_title_b">：</div>
#             </div>
#             <a class="bn_list_a" style="color:#2E6AB1" href="/Publication/PublicationIndex?PublicationID=17272432" onclick="showMouseButton(function () { _Layout_BlockUICustomSetting(function () { PjaxToOtherPage_type_FirstID_SecondID('/Publication/PublicationIndex', '', '17272432', ''); }); }, this); return false;">
#               國防雜誌
#             </a>
#           </div>
#               <div class="bn_list">
#                 <div class="bn_title">
#                   <div>並列刊名</div>
#                   <div class="bn_title_b">：</div>
#                 </div>
#                 <a class="bn_list_a" style="color:#2E6AB1" href="/Publication/PublicationIndex?PublicationID=17272432" onclick="showMouseButton(function () { _Layout_BlockUICustomSetting(function () { PjaxToOtherPage_type_FirstID_SecondID('/Publication/PublicationIndex', '', '17272432', ''); }); }, this); return false;">
#                   National Defense Journal
#                 </a>
#               </div>
#
#
#           <div class="bn_list">
#             <div class="bn_title">
#               <div>出版單位</div>
#               <div class="bn_title_b">：</div>
#             </div>
#             <div class="bn_list_wen">
#               國防大學
#             </div>
#           </div>
#
#
#
#
#               <div class="bn_list">
#                 <div class="bn_title">
#                   <div>DOI&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
#                   <div class="bn_title_b">：</div>
#                 </div>
#
#                 <div class="bn_list_a2_div">
#                   <a class="bn_list_a2" target="_blank" href="http://hyint.nhu.edu.tw:2420/10.6326/NDJ" onclick="openurl(this,'17272432'); return false;">
#                     10.6326/NDJ
#                   </a>
#                 </div>
#               </div>
#
#           <div class="bn_bottom">
#
#
#
#             <div class="bn_bottom_wen">
#                 <div style="display: inline;"> </div>
#
#             </div>
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
#   <div class="l_wen_div_all" id="tabE">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="l_wen_div">
#       <div class="f_news_imgdiv">
#         <img src="/EDM/學界快訊/GS.PNG" />
#       </div>
#       <div class="f_news_article">
#         <div class="f_news_title">
#           <span style="font-size: 16px;font-weight: bold;line-height: 19px">帶著走的Google Scholar，Quick Abstracts新功能上線</span>
#         </div>
#         <div class="f_news_wen">
#           覺得手機版的Google Scholar不好用？試試改良後相當適合帶著走的新版本！
#           <div style="padding-top: 8px;padding-bottom: 8px">今年三月起，Google Scholar為手機使用者準備了新的學術文獻瀏覽模式：完成檢索後，點選開啟快速預覽畫面，左右滑動切換不同文獻；先閱讀完整摘要與重要書目資訊，再選擇誰才是真正被需要的參考文獻。</div>
#           <a href="/EDM/%e5%ad%b8%e7%95%8c%e5%bf%ab%e8%a8%8a/20180511_ALnews_QuickAbstract.pdf" target="_blank" class="more">>> Quick-Abstracts功能介紹</a>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
#
#
# 				<div class="navigationTitle_new clearnaytitle">
# 	<div class="navigationTitleSymbol">
# 	</div>
# 	文獻類型導覽
# </div>
# <div class="content">
# 	<div class="alldiv">
# 		<div class="large_n">
# 			<div class="t_title_img">
# 				<img src="/Content/images/icon_J.gif" />
# 			</div>
# 			<div class="t_title_all">
# 				<div class="t_title">
# 					電子期刊
# 				</div>
# 			</div>
# 		</div>
# 		<div class="listcontentall" id="eJournal" style="display:block;">
#
#
# ...
# 							Ainosco Press 為華藝數位股份有限公司旗下之專業學術性出版社，致力...
# 						</a>
# 					</div>
# 				</div>
#
# 				<div class="one">
# 					<div class="up">
#                       <a href="http://www.ipress.tw/" target="_blank">
#                         <img src="/Content/images/spersLogo.jpg" alt="spersLogo" />
#                       </a>
# 					</div>
# 					<div class="txt">
#                       <a href="http://www.ipress.tw/" target="_blank">
#                         「華藝學術投稿平台」簡化編務流程，大幅提升工作效率。
#                       </a>
# 					</div>
# 				</div>
#
# 				<div class="one">
# 					<div class="up">
# 						<a href="http://www.iread.com.tw/" target="_blank">
# 							<img src="/Content/images/iReadLogo.jpg" alt="iReadLogo" />
# 						</a>
# 					</div>
# 					<div class="txt">
# 						<a href="http://www.iread.com.tw/aboutUs.aspx" target="_blank">紅利高額回饋！全館單筆消費滿100元，即可享有回饋。</a>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="top1">
#
#
#
#
#
# 				<div class="one">
# 					<div class="up">
# 						<a href="http://cetd.airiti.com/main/index" target="_blank">
# 							<img src="/Content/images/ETDSlogo.jpg" alt="airitiNatureLogo" />
# 						</a>
# 					</div>
# 					<div class="txt">
# 						<a href="http://cetd.airiti.com/main/index" target="_blank">將論文授權給華藝，可獲權利金回饋，更讓資料庫為您的論文服務！</a>
# 					</div>
# 				</div>
#
# 				<div class="one">
# 					<div class="up">
# 						<a href="http://hyint.nhu.edu.tw:2053/EDM/20140425/%E9%9F%93%E5%9C%8B%E6%AD%B7%E4%BB%A3%E6%96%87%E9%9B%86.html" target="_blank">
# 							<img src="/Content/images/Logo.png" alt="airitiArtLogo" />
# 						</a>
# 					</div>
# 					<div class="txt">
# 						<a href="http://hyint.nhu.edu.tw:2053/EDM/20140425/%E9%9F%93%E5%9C%8B%E6%AD%B7%E4%BB%A3%E6%96%87%E9%9B%86.html" target="_blank">
# 							韓國歷代文集
# 							<br />
# 							東亞文化交涉史的新發現，域外...
# 						</a>
# 					</div>
# 				</div>
#
#               <div class="one">
#                 <div class="up">
#                   <a href="http://hyint.nhu.edu.tw:2053/EDM/20140425/%E9%9F%93%E5%9C%8B%E5%9C%B0%E7%90%86%E9%A2%A8%E4%BF%97%E8%AA%8C.html" target="_blank">
#                     <img src="/Content/images/Logo.png" alt="airitiNatureLogo" />
#                   </a>
#                 </div>
#                 <div class="txt">
#                   <a href="http://hyint.nhu.edu.tw:2053/EDM/20140425/%E9%9F%93%E5%9C%8B%E5%9C%B0%E7%90%86%E9%A2%A8%E4%BF%97%E8%AA%8C.html" target="_blank">
#                     韓國地理風俗誌
#                     <br />
#                     涵蓋地理、風俗、語言、民俗等...
#                   </a>
#                 </div>
#               </div>
# 			</div>
#
# 		</div>
# 	</div>
# </div>
# <div class="downBG">
# 	<div class="downBGLeft">
# 	</div>
# 	<div class="downBGCenter">
# 	</div>
# 	<div class="downBGRight">
# 	</div>
# </div>
# 	</div>
# </div>
# <div class="rightIndex">
#   <!---AL國際需求部分   新增  start--->
#   <!-- 關閉回到舊版功能 阿吉 -->
#
# 	<!---AL國際需求部分   新增  end--->
#
# 	<div class="messageDynamic">
# 		<div class="officiallyRegisteredBlueTitleIndex">
# 	訊息動態
# </div>
# <div class="content">
# 		<a href="javascript:_Layout_DynamicMessageByID('201806290001');">
# 			<span class="odd1">
# 				<span class="txt">Airiti學界快訊：帶著...</span>
# 				<span class="circleTriangle"></span>
# 			</span>
# 		</a>
# 		<a href="javascript:_Layout_DynamicMessageByID('201806290002');">
# 			<span class="even1">
# 				<span class="txt">Airiti學界快訊：IN...</span>
# 				<span class="circleTriangle"></span>
# 			</span>
# 		</a>
# 		<a href="javascript:_Layout_DynamicMessageByID('201806290003');">
# 			<span class="odd1">
# 				<span class="txt">Airiti學界快訊：DO...</span>
# 				<span class="circleTriangle"></span>
# 			</span>
# 		</a>
# 		<a href="javascript:_Layout_DynamicMessageByID('201806290004');">
# 			<span class="even1">
# 				<span class="txt">Airiti學界快訊：道別...</span>
# 				<span class="circleTriangle"></span>
# 			</span>
# 		</a>
#
# 	<a href="javascript:_Layout_LoadBody('/Home/DynamicMessage');" class="blue">
# 		>>更多
# 	</a>
# </div>
# 	</div>
#
#
#
#
# <div id="QueryHistorical1" style="width:600px;padding:15px;">
#   <div class="bar">
#     <a href="javascript:_Layout_ShowHideLayers('QueryHistorical1','','hide');">
#       關閉
#       <img src="/Content/images/icon_x.gif" alt="close" width="18" height="17" align="absmiddle">
#     </a>
#   </div>
#   <div class="explainrank">
#     <div class="explainrankall_line">
#       <div class="explainrankall_line_title"><b>總解析次數：</b></div>
#       <div class="explainrankall_line_c">期刊所含DOI號碼解析次數總和</div>
#     </div>
#     <div class="explainrankall_line">
#       <div class="explainrankall_line_title"><b>文章平均解析次數：</b></div>
#       <div class="explainrankall_line_c">文章解析次數總和／真正解析文章筆數</div>
#     </div>
#     <div class="explainrankall_line">
#       <div class="explainrankall_line_title"><b>解析：</b></div>
#       <div class="explainrankall_line_c">以DOI號為連結前往目標的對應網址</div>
#     </div>
#     <br /><br />
#     <h1>什麼是DOI</h1>
#     <p>
#       DOI(Digital Object Identifier)為物件的數位辨識碼，發展僅歷經20年即成為國際數位物件的識別與互通標準。目前全球超過1.48億筆數位物件使用DOI做為永續超連結，同時藉由DOI動態識別特性，追蹤使用狀況、進行大數據分析，掌握國際能見度。
#
#     </p>
#     <h1>使用DOI作為永久連結</h1>
#     <p>
#
#       每個DOI號前面加上「<a href="http://hyint.nhu.edu.tw:2055/ " target="_blank">http://dx.doi.org/</a>」 便成為永久網址。
#       <br>
#       例如：
#       文獻的DOI:
#       <span class="redword"> 10.5870/airiti003</span>
#             <br />
#
#       此文獻的DOI的永久連結即為：
#       <a href="http://hyint.nhu.edu.tw:2055/10.5870/airiti003">
#         http://dx.doi.org/<span class="redword">10.5870/airiti003 </span>
#       </a>
#     </p>
#     <h1>查找DOI</h1>
#     <p>
#       若不確定查找的文獻是否已申請DOI，歡迎使用華藝提供的查詢工具
#       <a class="doisearch" href="http://www.airitischolar.com/doi/search/" target="blank" style="color: #2E6AB1;text-decoration:underline;">DOI比對器</a>
#     </p>
#   </div>
# </div>
#
#
# <div class="forrank_parent">
#   <div class="officiallyRegisteredBlueTitleIndex">
#     <div class="forDOItitle">華藝DOI熱門解析期刊</div>
#     <a class="right_hand" onclick="_Layout_ShowHideLayers('QueryHistorical1', '', 'show');"></a>
#   </div>
#   <div class="content">
#     <div class="forrank_tab">
#       <div class="tab2">
#         <div class="forrank_word_parent">
#           <a class="forrank_word" title="文章平均解析次數">文章平均解析次數</a>
#         </div><div class="viewonbg"></div>
#       </div>
#       <div class="tabline"></div>
#
#       <div class="tab1 viewon">
#         <div class="forrank_word_parent">
#           <a class="forrank_word" title="解析總次數">解析總次數</a>
#         </div>
#         <div class="viewonbg"></div>
#       </div>
#     </div>
#     <div class="forrank_all">
#       <div class="analyze_time">
#         <ul>
#           <li>
#             <div class="order_nodiv  no1"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6224/JN" target="_blank" onclick="openurl(this,'0047262x');return false;">護理雜誌</a>
#           </li>
#           <li>
# 	          <div class="order_nodiv  no2"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6142/VGHN" target="_blank" onclick="openurl(this,'02584727'); return false;">榮總護理</a>
#           </li>
#           <li>
# 	          <div class="order_nodiv  no3"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6320/FJM" target="_blank" onclick="openurl(this,'10281916'); return false;">臺灣醫學</a>
#           </li>
#
#           <li>
# 	          <div class="order_nodiv  no4"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6288/TJPH" target="_blank" onclick="openurl(this, 'a0000127'); return false;">臺灣公共衛生雜誌</a>
#           </li>
#           <li>
# 	          <div class="order_nodiv  no5"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6225/JNHR" target="_blank" onclick="openurl(this, '20729235'); return false;">護理暨健康照護研究</a>
#           </li>
#           <li>
#             <div class="order_nodiv  no6"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6199/NTULJ" target="_blank" onclick="openurl(this,'a0000446'); return false;">臺大法學論叢</a>
#           </li>
#           <li>
#             <div class="order_nodiv  no7"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6133/apjcn" target="_blank" onclick="openurl(this,'09647058'); return false;">Asia Pacific Journal of Clinical Nutrition</a>
#           </li>
#           <li>
# 	          <div class="order_nodiv  no8"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6220/joq" target="_blank" onclick="openurl(this, '10220690'); return false;">品質學報</a>
#           </li>
#           <li>
#             <div class="order_nodiv  no9"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6623/chem" target="_blank" onclick="openurl(this, 'P20160122002'); return false;">化學</a>
#           </li>
#           <li>
#             <div class="order_nodiv  no10"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6119/JMST" target="_blank" onclick="openurl(this, '10232796'); return false;">Journal of Marine Science and Technology</a>
#           </li>
#         </ul>
#       </div>
#       <div class="article_time" style="display:none;">
#         <ul>
#           <li>
# 	          <div class="order_nodiv  no1"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6227/jfda" target="_blank" onclick="openurl(this, '10219498'); return false;">藥物食品分析</a>
# 		  </li>
#           <li>
#             <div class="order_nodiv  no2"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6120/JoEMLS" target="_blank" onclick="openurl(this,'1013090x'); return false;">教育資料與圖書館學</a>
#           </li>
#           <li>
#             <div class="order_nodiv  no3"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6146/univj" target="_blank" onclick="openurl(this,'16822889'); return false;">大學圖書館</a>
#           </li>
#           <li>
#             <div class="order_nodiv  no4"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6493/SmartSci" target="_blank" onclick="openurl(this, '23080477'); return false;">Smart Science</a>
#           </li>
#           <li>
# 	          <div class="order_nodiv  no5"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6122/CJP" target="_blank" onclick="openurl(this, '05779073'); return false;">Chinese Journal of Physics</a>
#           </li>
#           <li>
# 	          <div class="order_nodiv  no6"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6124/JAAA" target="_blank" onclick="openurl(this,'19907729'); return false;">航空太空及民航學刊.系列B</a>
#           </li>
#           <li>
#             <div class="order_nodiv  no7"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6119/JMST" target="_blank" onclick="openurl(this, '10232796'); return false;">Journal of Marine Science and Technology</a>
#           </li>
#           <li>
#             <div class="order_nodiv  no8"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6133/apjcn" target="_blank" onclick="openurl(this, '09647058'); return false;">Asia Pacific Journal of Clinical Nutrition</a>
#           </li>
#           <li>
#             <div class="order_nodiv  no9"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6209/JORIES" target="_blank" onclick="openurl(this, 'P20151027006'); return false;">Asian Studies</a>
#           </li>
#           <li>
#             <div class="order_nodiv  no10"></div>
#             <a href="http://hyint.nhu.edu.tw:2420/10.6151/CERQ" target="_blank" onclick="openurl(this,'18144810'); return false;">當代教育研究季刊</a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </div>
#   <div class="rankupadte">
#     更新日期
#     2018/09/30
#   </div>
#   <div class="go_todoi_parent">
#     <a class="go_todoi" href="http://doi.airiti.com/" target="_blank">
#       前往了解 &gt;
#     </a>
#   </div>
# </div>
#
# <script language="javascript" type="text/javascript">
#   //客戶使用 Proxy 轉址，因導向到 DOI 再導回到 AL 造成使用者未登陸的狀態
#   //為避免客戶誤導，所有透過 DOI 轉址回 AL的連結，直接導向 AL 內部連結，以避免錯誤
#   //如果不是導回 AL 則不做此處理
#   function openurl(obj, PublicationID) {
#     //alert(obj.href);
#     $.ajax({
#       type: 'POST',
#       url: '/Home/BrowerURL',
#       data: JSON.stringify({ URL: obj.href }),
#       contentType: "application/json; charset=utf-8", //設定傳回server格式
#       success: function (data) { },
#       error: function (data) { }
#     });
#     window.open("/Publication/alPublicationJournal?PublicationID=" + PublicationID);
#   }
#   $(document).ready(function () {
#     try {
#       $(".forrank_tab .tab2").mouseover(function () {
#         $(this).addClass("viewon");
#         $(".forrank_tab .tab1").removeClass("viewon");
#         $(".article_time").css("display", "block");
#         $(".analyze_time").css("display", "none");
#       });
#       $(".forrank_tab .tab1").mouseover(function () {
#         $(this).addClass("viewon");
#         $(".forrank_tab .tab2").removeClass("viewon");
#         $(".article_time").css("display", "none");
#         $(".analyze_time").css("display", "block");
#       });
#       //$('#QueryHistorical1').hide();
#     } catch (e) {
#     }
#   });
# </script>
# 	<div class="update">
# 		<div class="officiallyRegisteredBlueTitleIndex">
# 	airiti 資料更新
# </div>
# <div class="content">
# 				<p>
# 					期刊文章
# 					<span class="redNumber">32,522,833</span>
# 					本
# 				</p>
# 				<p>
# 					會議論文集
# 					<span class="redNumber">2,694,145</span>
# 					本
# 				</p>
# 博碩士論文				<span class="redNumber">3,803,337</span>
# 本				<p>
# 					圖書
# 					<span class="redNumber">70,048</span>
# 					本
# 				</p>
#
# </div>
# <div class="date">
# 	更新日期
# 	2019/3/26
# </div>
# 	</div>
#
# 	<div class="messageDynamic">
# 		<div class="officiallyRegisteredBlueTitleIndex">
# 	答客問 Q&amp;A
# </div>
# <div class="content">
# 	<a href="javascript:_Layout_NewsByIDSearch('201806210001');">
# 		<span class="odd1">
# 			<span class="txt">答客問_收不到認證信</span>
# 			<span class="circleTriangle"></span>
# 		</span>
# 	</a>
# 	<a href="javascript:_Layout_NewsByIDSearch('201307020001');">
# 		<span class="even1">
# 			<span class="txt">答客問_全文空白或亂碼</span>
# 			<span class="circleTriangle"></span>
# 		</span>
# 	</a>
# 	<a href="javascript:_Layout_NewsByIDSearch('201109300003');">
# 		<span class="odd1">
# 			<span class="txt">答客問_購買點數問題</span>
# 			<span class="circleTriangle"></span>
# 		</span>
# 	</a>
# 	<a href="javascript:_Layout_NewsByIDSearch('201109300002');">
# 		<span class="even1">
# 			<span class="txt">答客問_下載全文相關問題</span>
# 			<span class="circleTriangle"></span>
# 		</span>
# 	</a>
# 	<a href="javascript:_Layout_NewsByIDSearch('201311270001');">
# 		<span class="odd1">
# 			<span class="txt">看不到「驗證碼」圖片？</span>
# 			<span class="circleTriangle"></span>
# 		</span>
# 	</a>
#
# 	<a href="javascript:_Layout_LoadBody('/Home/Service4');" class="blue">
# 		>>更多
# 	</a>
# </div>
# 	</div>
#
# </div>
#       </div>
#
#
#       <div class="footer">
#         <div class="top">
# 	<a href="http://hyint.nhu.edu.tw:2149/" target="_blank">關於華藝</a>│
# 	<a href="javascript:;" onclick="_Layout_LoadBody('/Home/Cooperation');">授權華藝</a>
# 	│
# 	<a href="javascript:;" onclick="_Layout_LoadBody('/Home/About');">關於airiti Library</a>
# 	│
# 	<a href="http://www.104.com.tw/jobbank/custjob/index.php?r=cust&j=4c70426d4c46402230683b1d1d1d1d5f2443a363189j99&jobsource=checkc" target="_blank">人才招募</a>
# 	│
# 	<a href="javascript:;" onclick="_Layout_LoadBody('/Home/Copyright');">著作權聲明</a>
# 	│
# 	<a href="javascript:;" onclick="_Layout_LoadBody('/Home/Privates');">隱私權聲明</a>
# 	│
# 	<a href="http://get.adobe.com/tw/reader/" target="_blank">點此下載
# 		<img src="/Content/images/download.gif" alt="download" />
# 		</a>
# </div>
# <div class="down">
# 	<span>
# 		客戶服務專線
# 		0800-000-747
# 	</span>
# 	<span>
# 		傳真
# 		02-2926-6016
# 	</span>
# 	<span>
# 		客服信箱
# 		：
#       lib@airiti.com
# 	</span>
# 	<span>
# 		服務時間：週一～五
# 		9:00~18:00
# 	</span>
# 	<span>
# 		地址：234台灣新北市永和區成功路一段80號18樓
# 	</span>
# 	<div>
# 		© 2011airiti Inc. All rights reserved.
# 		華藝數位股份有限公司
# 	</div>
# </div>
#       </div>
#
#     </div>
#
#
#     <div id="alSummaryListIframe">
#       <h2>
#         <a onclick="_Layout_ShowHideLayers('alSummaryListIframe', '', 'hide');">
#           <img class="hand" src="/Content/images/alSummaryListIframeClose.png" alt="close" width="15" height="15" />
#         </a>
#       </h2>
#     </div>
#
#
#     <div class="alSummaryListIframe1" id="alSummaryListIframe1">
#       <h2>
#         <a onclick="_Layout_ShowHideLayers('alSummaryListIframe1', '', 'hide');">
#           <img class="hand" src="/Content/images/alSummaryListIframeClose.png" alt="close" width="15" height="15" />
#         </a>
#       </h2>
#     </div>
#
#
#   </div>
#
#
#   <div id="memberPersonalInfoDiv"></div>
#   <div id="memberJoinDiv"></div>
#
#
# </body>
#
# </html>
